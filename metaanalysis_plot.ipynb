# %%
#META ANALYSIS 

import matplotlib.pyplot as plt
avg = 379.98 / 29
nir = (46 + 56 + 45) / 3
netms = [53.941,53.941,53.941]
emulation = [avg,avg,avg]
X = [2015]



import numpy as np 
import matplotlib.pyplot as plt 
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

X_axis = np.arange(len(X))
  
ax[0].bar(X_axis - 0.1, [nir], 0.1, label = 'National Inventory Report $^a$')
ax[0].bar(X_axis + 0, [53.941], 0.1, label = 'National Terrestrial Ecosystem Monitoring System$^b$')
ax[0].bar(X_axis +0.1,[avg],0.1,label = 'Emulation$^c$')
ax[0].set_title('AGB loss per year')
ax[0].set_ylabel('Mt C')
ax[0].set_xlabel('Study')
ax[0].set_xticks([])
ax[1].bar(X_axis - 0.1, [nir*30], 0.1, label = 'National Inventory Report $^a$')
ax[1].bar(X_axis, [1.726*1000], 0.1,label = 'National Terrestrial Ecosystem Monitoring System$^b$')
ax[1].bar(X_axis +0.1,[379.99],0.1,label = 'Emulation$^c$')
ax[1].set_title('Total AGB Lost over 30 years')
ax[1].set_ylabel('Mt C')
# ax.set_yscale('log')
plt.xticks(X_axis, X)
plt.suptitle("Above-Ground Biomass Estimate Study Comparison for Wood Harvest Impacts in Canada")
plt.legend(bbox_to_anchor=(1, 1))
plt.figtext(.1,-.2,'Fig.8 Comparison of studies quantifying wood harvest effects. $^a$ Only considers Hardwood Pool, not all AGB. $^b$ Considers all AGB. $^c$ Considers all woodharvest to be forested',wrap=True,fontsize=12)
#DO PLOT OF AGB TOTAL OVER THE 30 year, and in other subplot do avg loss per year
plt.show()
